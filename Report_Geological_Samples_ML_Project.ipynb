# %% [markdown]
# ## **Clustering Analysis of Obsidian from South American Volcanoes**

# %% [markdown]
# ## **ABSTRACT**

# %% [markdown]
# Introduction
#
# The Nazca Plate is an active oceanic tectonic plate that is subducting the South American Plate causing a chain of volcanoes on and off the coast of Western South America. A type of volcanic rock, obsidian, naturally forms when lava cools rapidly with minimal crystal growth. Obsidian are produced from felsic lavas which are rich in lighter elements such as silicon, aluminium, sodium, and potassium. These geochemical properties characterize Obsidian rocks but between these obsidian samples, there are a range in elemental weight. The difference in elemental weight can be due to different conditions that occured to the lava and when the lava solidified. Through looking at the geochemical fluxations that occur to different samples of Obsidan rock, we can understand the chemical change in these samples and where they are located. Chemical changes in obsidian samples can provide insight into Nazca-South American subduction zone and the mantle conditions. In addition, Obsidian samples are commonly used in different cultures for its hard strength and ability to fracture and create sharp edges. To be able to understand where obsidian samples are located allow anthropologist to understand where these cultures would go explore to obtain these samples.
#
# Since volcanic acitivty along Western South America is vast it is possible that the geochemistry in obsidian samples are different based on potentially there being region differences. With the subduction zone being the main geologic activity in these regions which would provide the lava needed for these volcanic eruptions, there is a possibility that the differences can be difficult to identify.

# %% [markdown]
# Background

# %% [markdown]
# Data
#
# The data used for this project comes from the EarthChem Database. This database has geochemical data from various papers. This project uses various papers that looked at obsidian samples in the Western South American region. These papers used various methodologies to conduct their geochemical analysis ( ie: Microprob, XRF, XRD). The majority of papers selected had samples located in inland specifically on the Andean Plateau. There are few samples collected in the water along the coast.

# %% [markdown]
# Methods
#
# For this project, we used both unsupervised and supervised learning algorithms in order to differentiate clusters based on location
#
#
# - StandardScaler
# - PCA
# - Kmeans
# - DecisionTree
#
# Also, not only we used Papers as a reference (target variable) we used Rock Type in another section and implemented the following for suervised and unsupervised learning methods
#
#
#
# *   Standard Scalar
# *   PCA
# *   LDA
# *   Logistic Regression
# *   Random Forest
# *   Decision Trees
# *   KNN
# *   KMeans
# *   DBSCAN
#
# *   Hierarchical Clustering
# *   List item

# %% [markdown]
# Results

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From the heatmap we see that are some elements that are moderately correlated with each other ( Ex: TIO2 vs. FEOT). This is to be expected as some minerals ( which are composed of elements) are created under certain conditions in which different elements may appear or disappear.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Out of 15 components, we see that the data is influenced by 1-2 principal components

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here we see that looking at PCA 1 and PCA 2 we see that there is a cluster that has a significant amount of samples that is separated into two at PCA 1= 0. Kmeans was conducted comparing geochemical data with a single value location. The single value location calculated using the Haversine formula which uses the samples longitude and latitude.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Looking at coordinate and clusters formed from Kmeans, we see that these clusters are located in various locations. Indicating that there is not one location where the samples are of similar geochemistry.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using the cluster labels from Kmeans, we conducted a RandomForest. From our training data, we had a mean absolute error of 0.28 degrees and an accuracy of 85.85%. When we extract the most important features, we found that “BA” had an importance of 0.69 and “SR” had an important of 0.22. Next, we extracted the most two important features “BA” and “SR” our mean absolute error becomes 183.63 degrees with an accuracy of 97.72%. Displayed is our test data. Our test data had a mean absolute error of 0.09 degrees and accuracy of 96.05 %.

# %% [markdown]
# The above mentioned study is based on the Research paper as a reference and the below - following is based on **Rock Type**

# %% [markdown]
# ![Screen Shot 2021-05-26 at 23.26.58.png](data:image/png;base64,...)

# %% [markdown]
# We implemented PCA in order to visualize the obsidians seperately and to perform dimension reductionality. Since the above plot wasn't clear, after rotation of axis, below was the output.

# %% [markdown]
# ![Screen Shot 2021-05-26 at 23.27.36.png](data:image/png;base64,...)

# %% [markdown]
# In this using PCA1 and PCA2 significant amount of clusters can be visualized. Using the above data, the same was plotted in 2D on Longitude and Latitude.

# %% [markdown]
# ![Screen Shot 2021-05-04 at 18.58.28.png](data:image/png;base64,...)

# %% [markdown]
# KMeans
#
# The following code trains a k-means model and runs prediction on the data set.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# But since the above model wasn't that helpful, using make_blob(), the following was the output

# %% [markdown]
# ![Screen Shot 2021-05-26 at 23.39.56.png](data:image/png;base64,...)

# %% [markdown]
# Conclusion
#
# Obsidian samples from Western South American volcanoes are more challenging to cluster than expected. There are a number of issues for this project where we couldn't obtain clear clusters from the data. It is possible that due to lack of crystal growth which occurs in obsidian allows for more complex machine algorithms to detect differences between samples within the same geologically active region.

# %% [markdown]
# Contribution

# %% [markdown]
# ![Screen Shot 2021-05-26 at 23.16.48.png](data:image/png;base64,...)
